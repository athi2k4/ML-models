# %%
import time
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt

# Ensure you're using the right KerasCV version that includes StableDiffusion
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512)

# Generate images
images = model.text_to_image("astronaut riding a horse", batch_size=1)

# The images generated by text_to_image might be in float32 format, so convert to uint8
images = (images * 255).astype("uint8")

def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")

# Plot the generated images
plot_images(images)
plt.show()
# Out:
# 2024-07-06 06:06:17.279793: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-06 06:06:17.279923: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-06 06:06:17.441976: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE
# ...
# 1356917/1356917 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 492466864/492466864 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# ...
